# %% [markdown]
# <a href="https://colab.research.google.com/github/NEFTACAMFIG/Proyecto-2-Data-Cleaning/blob/main/proyecto2_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **VIOLENCIA EN MÉXICO**

# %% [markdown]
# ![mexican-flag-gf6bd65253_640.png](data:image/png;base64,...)

# %% [markdown]
# ## Objetivo

# %% [markdown]
# La violencia en México es un tema recurrente por lo que nos parece importante conocer algunos datos sobre este tema y averigurar ¿Que este pasando con la violencía? ¿Hay algun factor que la propicie? etc.

# %%
#Importando las librerias necesarias para procesar y visualizar los datos
import numpy as mp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from IPython.display import HTML
import plotly.express as px

# %% [markdown]
# Estos son los datos que se van a utilizar para realizar el análisis

# %%
#Importando los datos con los que se van a trabajar
df_2015 = pd.read_csv("https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2015_datos_violencia_delictiva.csv")
df_2016 = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2016_datos_violencia_delictiva.csv')
df_2017 = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2017_datos_violencia_delictiva.csv')
df_2018 = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2018_datos_violencia_delictiva.csv')
df_2019 = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2019_datos_violencia_delictiva.csv')
df_2020 = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/2020_datos_violencia_delictiva.csv')
df_PIB = pd.read_csv('https://raw.githubusercontent.com/NEFTACAMFIG/Proyecto2.DEV.F/main/PIBE_2.csv')

# %%
#df_2020.head()

# %% [markdown]
# # **Pregunta 1. ¿Cuál es la tendencia de actos delictivos en México a traves de los años?**

# %% [markdown]
# Para responder la primera pregunta, se obtiene el total de delitos cometidos en un año en todas las entidades del país. Este total se obtiene para los datos desde el 2015-2020 esperando encontrar alguna tendencia en los datos

# %% [markdown]
# # 2015

# %%
df_T2015 = df_2015.copy() #Se crea una copia de los datos que se van a trabajar

#Se crea una lista, con el nombre de las columnas de los datos
suma_lista = list(df_T2015)
#Se eliminan de la lista la columnas que no se van a utilizar
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

#Se agrega la columna "Total", la cual contiene la suma de todos los delitos realizados en un año por cada municipio 
df_T2015['Total'] = df_T2015[suma_lista].sum(axis=1)

#Se suman todos los delitos realizados en un año para conocer la cifra total
df_T2015 = df_T2015['Total'].groupby(df_T2015['Año']).sum()
df_T2015 = df_T2015.to_frame().reset_index()
df_T2015
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # This is added back by InteractiveShellApp.init_path()
#     Año    Total
# 0  2015  1657804

# %% [markdown]
# # 2016

# %%
df_T2016 = df_2016.copy()

suma_lista = list(df_T2016)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

df_T2016['Total'] = df_T2016[suma_lista].sum(axis=1)

df_T2016 = df_T2016['Total'].groupby(df_T2016['Año']).sum()
df_T2016 = df_T2016.to_frame().reset_index()
df_T2016
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#     Año    Total
# 0  2016  1761830

# %% [markdown]
# # 2017

# %%
df_T2017 = df_2017.copy()

suma_lista = list(df_T2017)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

df_T2017['Total'] = df_T2017[suma_lista].sum(axis=1)

df_T2017 = df_T2017['Total'].groupby(df_T2017['Año']).sum()
df_T2017 = df_T2017.to_frame().reset_index()
df_T2017
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#     Año    Total
# 0  2017  1939497

# %% [markdown]
# # 2018

# %%
df_T2018 = df_2018.copy()

suma_lista = list(df_T2018)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

df_T2018['Total'] = df_T2018[suma_lista].sum(axis=1)

df_T2018 = df_T2018['Total'].groupby(df_T2018['Año']).sum()
df_T2018 = df_T2018.to_frame().reset_index()
df_T2018
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#     Año    Total
# 0  2018  1989930

# %% [markdown]
# # 2019

# %%
df_T2019 = df_2019.copy()

suma_lista = list(df_T2019)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

df_T2019['Total'] = df_T2019[suma_lista].sum(axis=1)

df_T2019 = df_T2019['Total'].groupby(df_T2019['Año']).sum()
df_T2019 = df_T2019.to_frame().reset_index()
df_T2019
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#     Año    Total
# 0  2019  2071164

# %% [markdown]
# # 2020

# %%
df_T2020 = df_2020.copy()

suma_lista = list(df_T2020)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

df_T2020['Total'] = df_T2020[suma_lista].sum(axis=1)

df_T2020 = df_T2020['Total'].groupby(df_T2020['Año']).sum()
df_T2020 = df_T2020.to_frame().reset_index()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %% [markdown]
# # Datos 2015-2020

# %% [markdown]
# Se unen los datos obtenidos para formar un nuevo Dataframe con todos los datos obtenidos en las secciones anteriores

# %%
#Con el comando concat se unen los datos obtenidos de los procesos anteriores, y se resetan los indices para para evitar duplicados y acomodar nuestros datos 
df_Total = pd.concat([df_T2015,df_T2016,df_T2017,df_T2018,df_T2019,df_T2020])
df_Total = df_Total.reset_index()

# %% [markdown]
# # Visualización de los resultados

# %% [markdown]
# Se escogieron 2 gráficas para visualizar los resultados, gráfica de barras y linea de tendencia, para saber si hay una tendencia a lo largo de los años respecto a los delitos cometidos en México

# %%
sns.set()
fig, axes = plt.subplots(1,2)
ax = sns.barplot(data = df_Total, x = 'Año', y = 'Total',ax=axes[0])
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,fontsize = 15)
ax.set_title('Total de delitos 2015-2020',fontsize = 25)
ax.set_ylabel('Total de delitos cometidos',fontsize = 20)
ax.set_xlabel('Año',fontsize = 20)

bx = sns.lineplot(data=df_Total, x='Año', y = 'Total', ax=axes[1])
bx.set_title('Tendencia de delitos 2015-2020',fontsize = 25)
bx.set_xticklabels(['2015','2015','2016','2017','2018','2019','2020'],fontsize = 15)
bx.set_ylabel('Total de delitos cometidos',fontsize = 20)
bx.set_xlabel('Año',fontsize = 20)

plt.rcParams["figure.figsize"] = (20,10)
fig.tight_layout()

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Los delitos cometidos en México tenian una tendencia positiva hasta el año 2020, algunos factores que podrían haber afectado al cambio de tendencia son: el cambio de politica hacia la seguridad de los ciudadanos, mejoramiento del sistema seguridad en el país o un cambio de pensamiento entre la sociedad teniendo como resultado una menor incidencia delictiva.
#
# Sin embargo el factor que podría tener más fuerza y el detonante del cambio de tendencia podría ser la pandemia por COVID-19, debido a que la movilidad de las personas se limito en gran medida los delicuentes no encontraban personas a las cuales hacer daño por lo que el número de delitos cometidos bajo considerablemente

# %% [markdown]
# # **Pregunta 2. ¿La violencia tiene una correlación con el PIB que genera cada estado?**

# %% [markdown]
# Para responder esta pregunta se tuvo que tomar otro Dataset, esta vez de la página del INEGI, el cual contiene los datos de PIB por estado desde el año 2003 y hasta el año 2020. Se escogio analizar el año 2019 ya que marca el fin de una tendencia que estaban siguiendo los datos. Ademas el año 2020 marco el inicio de la pandemia de covid 19, por lo que para analizar estos datos se tendrian que analizar probablemente más factores

# %%
#df_PIB.head(10)

# %% [markdown]
# Procesando los datos para obtener el PIB por entidad federativa en el año 2019

# %%
df_PIB1 = df_PIB.copy() #Se hace una copia del Dataset original
df_PIB1 = df_PIB1.drop(['2003','2004','2005','2006','2007',
          '2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2020 P'],axis=1)#Se eliminan las columnas de datos que no se utilizaran
df_PIB1 = df_PIB1.drop([0,1,2,3,4,5], axis=0)#Se eliminan las filas de datos que no se utilizaran
df_PIB1 = df_PIB1.reset_index()
df_PIB1= df_PIB1.drop(df_PIB1[df_PIB1['index']>37].index)#Más filas que no se utilizaran
df_PIB1 = df_PIB1.drop(['index'],axis=1)

df_PIB1 = df_PIB1.rename(columns = {'Concepto': 'Entidad', '2019 R':'PIB', 'Total':'Total de delitos cometidos'})#Se renombran las columnas 
#df_PIB1#.head(32)

# %% [markdown]
# Procesando los datos para obtener el total de delitos cometidos por entidad federativa en el año 2019

# %%
df_2019C = df_2019.copy()#Se hace una copia del Dataset original

#Se remueven las columnas con valores numericos y que no se utilizaran en nuestra siguiente operación
suma_lista = list(df_2019C)
suma_lista.remove('Clave_Ent')
suma_lista.remove('Año')
suma_lista.remove('Cve. Municipio')

#Se suman todos los datos cometidos a lo largo del año
df_2019C['Total de delitos cometidos'] = df_2019C[suma_lista].sum(axis=1)
#df_2019C.head()

#Se agrupan los datos por entidad federativa
df_2019CF = df_2019C['Total de delitos cometidos'].groupby(df_2019C['Entidad']).sum()
df_2019CF = df_2019CF.to_frame().reset_index()

#df_2019CF
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Se unen los datos de delitos cometidos por entidad federativa y el PIB por entidad federativa para crear un nuevo Dataset que contenga estos datos

# %%
#Se unen los datos del PIB por entidad federativa y los datos de los delitos cometidos por entidad federativa
df_PIBM = pd.merge(df_PIB1,df_2019CF)
df_PIBM = df_PIBM.reindex(columns =['Total de delitos cometidos','PIB','Entidad'])
df_PIBM2 = df_PIBM.copy() 
df_PIBM = df_PIBM.pivot_table('PIB','Total de delitos cometidos','Entidad')

# %% [markdown]
# # Visualización de resultados

# %%
sns.color_palette('dark')
plt.figure(figsize=(30,10))
cx = sns.heatmap(df_PIBM, cmap='viridis',square = True, robust = True, linewidth = 1, xticklabels = True)
cx.set_title('Correlación de delitos cometidos y PIB por entidad federativa', fontsize = 20)
cx.set_ylabel('Total de delitos cometidos',fontsize = 20)
cx.set_xlabel('Entidad',fontsize = 20)
plt.show()

# %% [markdown]
# Se escogío otra visualización para poder ver mejor la correlación de los datos PIB - Delitos cometidos

# %%
fig = px.scatter(df_PIBM2, x = 'PIB', y = 'Total de delitos cometidos',
    color = 'Entidad', size = 'PIB')
fig.update_layout(title_text = 'Relación de PIB - Delitos cometidos por entidad federativa en México 2019', title_x = 0.42)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0b6ed05d-93ed-4c96-b25c-801353b16ee1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b6ed05d-93ed-4c96-b25c-801353b16ee1")) {                    Plotly.newPlot(                        "0b6ed05d-93ed-4c96-b25c-801353b16ee1",                        [{"hovertemplate":"Entidad=Aguascalientes<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Aguascalientes","marker":{"color":"#636efa","size":[222456.2],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Aguascalientes","orientation":"v","showlegend":true,"x":[222456.2],"xaxis":"x","y":[38429],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Baja California<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Baja California","marker":{"color":"#EF553B","size":[575342.2509999999],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Baja California","orientation":"v","showlegend":true,"x":[575342.2509999999],"xaxis":"x","y":[104013],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Baja California Sur<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Baja California Sur","marker":{"color":"#00cc96","size":[158953.10499999998],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Baja California Sur","orientation":"v","showlegend":true,"x":[158953.10499999998],"xaxis":"x","y":[22644],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Campeche<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Campeche","marker":{"color":"#ab63fa","size":[517311.384],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Campeche","orientation":"v","showlegend":true,"x":[517311.384],"xaxis":"x","y":[2312],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Coahuila de Zaragoza<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Coahuila de Zaragoza","marker":{"color":"#FFA15A","size":[603930.571],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Coahuila de Zaragoza","orientation":"v","showlegend":true,"x":[603930.571],"xaxis":"x","y":[52937],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Colima<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Colima","marker":{"color":"#19d3f3","size":[109109.572],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Colima","orientation":"v","showlegend":true,"x":[109109.572],"xaxis":"x","y":[26554],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Chiapas<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Chiapas","marker":{"color":"#FF6692","size":[261697.34900000005],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Chiapas","orientation":"v","showlegend":true,"x":[261697.34900000005],"xaxis":"x","y":[23294],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Chihuahua<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Chihuahua","marker":{"color":"#B6E880","size":[572966.871],"sizemode":"area","sizeref":7832.697262500001,"symbol":"circle"},"mode":"markers","name":"Chihuahua","orientation":"v","showlegend":true,"x":[572966.871],"xaxis":"x","y":[71837],"yaxis":"y","type":"scatter"},{"hovertemplate":"Entidad=Ciudad de M\u00e9xico<br>PIB=%{marker.size}<br>Total de delitos cometidos=%{y}<extra></extra>","legendgroup":"Ciudad de M\u00e9xico","marker":{"color":"#FF97FF","size":[3133078.90 ...

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# 1.   Hay una correlación entre los delitos cometidos por entidad y el PIB
# 2.   En cuanto mas grande sea el PIB hay mas delitos cometidos
